# %%
name = "amargurav"
print(len(name))
# Out:
# 9

# %%
name = "amar"

print(len(name))
print(name.startswith("am"))
print(name.endswith("av"))
print(name.capitalize())
# Out:
# 4
# True
# False
# Amar
