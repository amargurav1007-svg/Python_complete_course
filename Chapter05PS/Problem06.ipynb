# %%
d = { }

name = input("Enter friend namee: ")
lang = input("Enter lang name : ")

d.update({name:lang})


d = { }

name = input("Enter friend namee: ")
lang = input("Enter lang name : ")

d.update({name:lang})

d = { }

name = input("Enter friend namee: ")
lang = input("Enter lang name : ")

d.update({name:lang})

d = { }

name = input("Enter friend namee: ")
lang = input("Enter lang name : ")

d.update({name:lang})


print(d)
# Out:
# {'divyatwa': 'codee'}

# %%
d = {}

name = input("Enter friends name: ")
lang = input("Enter Language name: ")
d.update({name: lang})

name = input("Enter friends name: ")
lang = input("Enter Language name: ")
d.update({name: lang})

name = input("Enter friends name: ")
lang = input("Enter Language name: ")
d.update({name: lang})

name = input("Enter friends name: ")
lang = input("Enter Language name: ")
d.update({name: lang})


print(d)
# Out:
# {'amar': 'c', 'shubham': 'd', 'sp': 'e', 'divys': 'w'}
