# %%
words = {
    "madad": "Help",
    "kursi": "Chair",
    "billi": "Cat"
}

word = input("Enter the word you want meaning of: ")

print(words[word])
# Out:
# Help

# %%
words = { 


    "madad": "Help",   
     "kursi": "Chair",
    "billi": "Cat"  
}

word = input ("Entert the name of the word you want meaning of: ")

print(words[word])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[3], line 11
#       1 words = {
#       2
#       3
#    (...)      6     "billi": "Cat"
#       7 }
#       9 word = input ("Entert the name of the word you want meaning of: ")
# ---> 11 print(words[word])
#
# KeyError: 'madatr'
