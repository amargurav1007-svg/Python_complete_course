# %%
s1 = {1, 45, 6, 78}  
s2 = {7, 8, 1, 78}

print(s1.union(s2))
print(s1.intersection(s2))
# Out:
# {1, 6, 7, 8, 45, 78}
# {1, 78}

# %% [markdown]
# #union take both values
# ## intersection takes only common values
