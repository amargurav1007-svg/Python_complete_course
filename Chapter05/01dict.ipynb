# %%
marks = { "Harry": 50,
         "Onkar": 60,
          "vikki": 70, 
          }
print("Marks of Harry:", marks["Harry"])
# Out:
# Marks of Harry: 50

# %%
d = {} # Empty dictionary
marks = {
    "Harry": 100,
    "Shubham": 56,
    "Rohan": 23
}


# print(marks, type(marks))
print(marks["Harry"])
# Out:
# 100
