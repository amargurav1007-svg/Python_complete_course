# %%
#How to raad file in python 
#create a file named file.txt and write something inside it
#Then run this code

f = open("file.txt", "r")
data = f.read()
print(data)
f.close()
# Out:
#  a = "Ram is a good boy"

# %%
"""ArithmeticErrorzzzza = "Harry is good boy "

f = open(file.txt)
data = f.read()
print(data)
f.close()
# Out:
#   Cell In[8], line 1
#     """ArithmeticErrorzzzza = "Harry is good boy "
#     ^
# _IncompleteInputError: incomplete input
