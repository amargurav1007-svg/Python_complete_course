# %% [markdown]
# #we can see how to write

# %%
st = "Hey Harry you are amazing"

f = open("myfile.txt", "w") #w is for write #f= open the file

f.write(st) #write the string in the file 

f.close() #close the file

# %%
a = "hi amar how are you"


f = open("file.txt", "w")

f.write(a)
f.close()
