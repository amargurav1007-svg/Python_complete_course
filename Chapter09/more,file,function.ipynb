# %% [markdown]
# #f.readlines() represent list of lines

# %%
f = open("file.txt")

# lines = f.readlines()
# print(lines, type(lines))

# line1 = f.readline()
# print(line1, type(line1))

# line2 = f.readline()
# print(line2, type(line2))

# line3 = f.readline()
# print(line3, type(line3))

# line4 = f.readline()
# print(line4, type(line4))

# line5 = f.readline()
# print(line5 =="")
line = f.readline()
while(line != ""):
    print(line)
    line = f.readline()

f.close()
# Out:
# hi amar how are you
#
# today is monday
#
# Twinkle Twinkle little star
#
# OLD IS GOLD

# %%
f = open("file.txt")

lines = f.readlines()   #f.realines() returns a list of lines

print(lines), type(lines) #  

f.close()
# Out:
# ['hi amar how are you\n', 'today is monday\n', 'Twinkle Twinkle little star\n', 'OLD IS GOLD \n']
