# %%
l = ["Harry", "Soham", "Sachin", "Rahul"]

for name in l:
    if name.startswith("H"):
        print(f"Hello {name}")
# Out:
# Hello Harry

# %%
l = ["Harry", "Soham", "Sachin", "Rahul"]

for name in l:
    if(name.startswith("S")):
        print(f"Hello {name}")
# Out:
# Hello Soham
# Hello Sachin
