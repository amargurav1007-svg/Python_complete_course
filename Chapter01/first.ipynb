# %%
name = "Amar"

# %%
name
# Out:
# 'Amar'

# %%
print("Hello World")
# Out:
# Hello World

# %%
print("hello world")
# Out:
# hello world

# %%
# !pip install pyjokes
# Out:
# ...
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pyjokes

# print("Printing Jokes...")

# This prints a random joke
# print= print a random joke 
joke = pyjokes.get_joke()
print(joke)

# this is my case
# this is my Code
#  this is nott my
# Out:
# I have a dream: 1073741824 bytes free.
