# %%
letter = '''Dear <|Name|>, 
You are selected! 
<|Date|> '''

print(letter.replace("<|Name|>", "Harry").replace("<|Date|", "24 September 2050"))
# Out:
# Dear Harry,
# You are selected!
# 24 September 2050>

# %%
letter = '''Dear <|Name|>, 
You are selected! 
<|Date|> '''

print(letter.replace("<|Name|>", "Amar").replace("<|Date|", "24 September 2050"))
# Out:
# Dear Amar,
# You are selected!
# 24 September 2050>
