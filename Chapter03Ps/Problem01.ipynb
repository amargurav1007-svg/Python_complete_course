# %%
name = input("Enter your name: ")

print(f"Good Morning {name}")
# Out:
# Good Morning Amar

# %%
name = input("Enter Your name: " )

print(f"Good Afternoon {name}")
# Out:
# Good Afternoon Amar
