# %% [markdown]
# #functions With Arguments

# %%
def goodDay(name, ending):
    print("Good Day, " + name)
    print(ending)
    return "ok"

a = goodDay("Harry", "Thank you") 
print(a)
# Out:
# Good Day, Harry
# Thank you
# ok

# %%
def goodDay():
    print("good Day, Amar")
    print("Thank you")

    a = goodDay()
    print(a)
