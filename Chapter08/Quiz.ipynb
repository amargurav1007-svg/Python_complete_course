# %%
def goodDay():
    print("Good Day")

goodDay()
# Out:
# Good Day

# %%
def goodDay  ():
    print("Good Day Amar")

goodDay()
badday()
# Out:
# Good Day Amar
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 5
#       2     print("Good Day Amar")
#       4 goodDay()
# ----> 5 badday()
#
# NameError: name 'badday' is not defined
