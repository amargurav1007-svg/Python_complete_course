# %% [markdown]
# # Tupple is immutable cannot change

# %%
a = (34, 234, "Harry")

a[2] = "Larry"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 a = (34, 234, "Harry")
# ----> 3 a[2] = "Larry"
#
# TypeError: 'tuple' object does not support item assignment
