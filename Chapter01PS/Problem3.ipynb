# %%
import os

# Select the directory whose content you want to list 
directory_path = '/'

# Use the os module to list the directory content 
contents = os.listdir(directory_path)

# Print the contents of the directory 
print(contents)
# Out:
# ['$RECYCLE.BIN', '3uToolsV3', 'c drive backup', 'CLINIMINDS', 'Digial Marketing', 'GIT', 'msdownld.tmp', 'NP DATA BACKUP', 'python', 'Resume SV.docx', 'songs', 'System Volume Information', 'VS Code']
