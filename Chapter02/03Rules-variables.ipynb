# %% [markdown]
#  ##Rules for variables

# %%
a = 23
aaa = 56
harry = 35
sammer = 45
@sameer = 45 #we cannot use @ 

s@meer =45 #we cannot use @
# Out:
#   Cell In[1], line 5
#     @sameer = 45 #we cannot use @
#      ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?
