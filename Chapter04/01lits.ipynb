# %%
friends = ["Apple", "Orange", 5, 345.06, False, "Aakash", "Rohan"]

print(friends[0])
friends[0] = "Grapes" # Unlike Strings lists are mutable

print(friends[0])
print(friends[1:4])
print(friends[1:3])
# Out:
# Apple
# Grapes
# ['Orange', 5, 345.06]
# ['Orange', 5]
